# %%
import pandas as pd 
import matplotlib
dataset = pd.read_csv("missingmarks_clean_data.csv")
import seaborn as sns

# %%
sns.set_style('darkgrid')
matplotlib.rcParams['font.size'] = 14
matplotlib.rcParams['figure.figsize'] = (10, 6)
matplotlib.rcParams['figure.facecolor'] = '#000000'

# %%
dataset.head(10)
# Out:
#    institution  system  data_loss_gen  data_loss_human  data_loss_machine  \
# 0        10602       1              2                3                  4
# 1        10612       1              2                3                  3
# 2        10597       1              2                1                  1
# 3        10597       2              2                2                  4
# 4        10597       1              1                1                  2
# 5        10597       1              1                1                  4
# 6        10602       1              2                1                  1
# 7        10592       1              1                3                  2
# 8        10592       1              1                3                  3
# 9        10612       1              2                2                  1
#
#    data_loss_hybrid  system_error_chance  feature
# 0                 1                    1        0
# 1                 1                    1        0
# ...

# %%
dataset.tail(10)
# Out:
#        institution  system  data_loss_gen  data_loss_human  data_loss_machine  \
# 10037        10597       1              2                1                  1
# 10038        10617       1              2                2                  2
# 10039        10602       1              2                1                  1
# 10040        10617       1              2                2                  2
# 10041        10622       2              2                2                  2
# 10042        10592       1              1                3                  2
# 10043        10607       1              2                2                  2
# 10044        10627       2              2                2                  2
# 10045        10627       2              2                2                  2
# 10046        10592       1              1                3                  4
#
#        data_loss_hybrid  system_error_chance  feature
# 10037                 2                    1        0
# ...

# %%
dataset.shape
# Out:
# (10047, 8)

# %%
dataset.isnull().sum()
# Out:
# institution            0
# system                 0
# data_loss_gen          0
# data_loss_human        0
# data_loss_machine      0
# data_loss_hybrid       0
# system_error_chance    0
# feature                0
# dtype: int64

# %%
dataset.describe().T
# Out:
#                        count          mean        std      min      25%  \
# institution          10047.0  10607.570319  12.004388  10592.0  10597.0
# system               10047.0      1.227630   0.419323      1.0      1.0
# data_loss_gen        10047.0      1.781925   0.412959      1.0      2.0
# data_loss_human      10047.0      1.977904   0.668173      1.0      2.0
# data_loss_machine    10047.0      1.832288   0.766250      1.0      1.0
# data_loss_hybrid     10047.0      1.764905   0.424079      1.0      2.0
# system_error_chance  10047.0      1.387379   0.487176      1.0      1.0
# feature              10047.0      0.838260   0.368230      0.0      1.0
#
#                          50%      75%      max
# institution          10607.0  10617.0  10627.0
# system                   1.0      1.0      2.0
# data_loss_gen            2.0      2.0      2.0
# data_loss_human          2.0      2.0      3.0
# data_loss_machine        2.0      2.0      4.0
# ...

# %%
dataset.groupby("feature").count()
# Out:
#          institution  system  data_loss_gen  data_loss_human  \
# feature
# 0               1625    1625           1625             1625
# 1               8422    8422           8422             8422
#
#          data_loss_machine  data_loss_hybrid  system_error_chance
# feature
# 0                     1625              1625                 1625
# 1                     8422              8422                 8422

# %%
import seaborn as sns
import matplotlib.pyplot as plt 
import plotly.express as px

# %%
fig = px.histogram(dataset, x='system', marginal='box', title='System Distribution')
fig.update_layout(bargap=0.1)
fig.show()

# %%
fig = px.histogram(dataset, x='data_loss_gen', marginal='box', title='System Distribution')
fig.update_layout(bargap=0.1)
fig.show()

# %%
fig = px.histogram(dataset, x='data_loss_human', marginal='box', title='System Distribution')
fig.update_layout(bargap=0.1)
fig.show()

# %%
fig = px.histogram(dataset, x='data_loss_machine', marginal='box', title='System Distribution')
fig.update_layout(bargap=0.1)
fig.show()

# %%
cols = ['data_loss_gen', 'data_loss_human', 'data_loss_machine', 'data_loss_hybrid', 'system_error_chance', 'feature']

# %%
sns.boxplot(data=dataset[cols[0]])
# Out:
# <AxesSubplot:>

# %%
sns.boxplot(data=dataset[cols[1]])
# Out:
# <AxesSubplot:>

# %%
sns.boxplot(data=dataset[cols[2]])
# Out:
# <AxesSubplot:>

# %%
sns.boxplot(data=dataset[cols[3]])
# Out:
# <AxesSubplot:>

# %%
sns.boxplot(data=dataset[cols[4]])
# Out:
# <AxesSubplot:>

# %%
sns.boxplot(data=dataset[cols[5]])
# Out:
# <AxesSubplot:>

# %%
plt.title('System vs Data Loss Human')
sns.barplot(data=dataset, x='institution', y='data_loss_human', alpha=0.7)
# Out:
# <AxesSubplot:title={'center':'System vs Data Loss Human'}, xlabel='institution', ylabel='data_loss_human'>

# %%
plt.title('System vs Data Loss Machine')
sns.barplot(data=dataset, x='institution', y='data_loss_machine', alpha=0.7)
# Out:
# <AxesSubplot:title={'center':'System vs Data Loss Machine'}, xlabel='institution', ylabel='data_loss_machine'>

# %%
plt.title('System vs Data Loss Hybrid')
sns.barplot(data=dataset, x='institution', y='data_loss_hybrid', alpha=0.7)
# Out:
# <AxesSubplot:title={'center':'System vs Data Loss Hybrid'}, xlabel='institution', ylabel='data_loss_hybrid'>

# %%
plt.title('System vs Error Chance')
sns.barplot(data=dataset, x='institution', y='system_error_chance', alpha=0.7)
# Out:
# <AxesSubplot:title={'center':'System vs Error Chance'}, xlabel='institution', ylabel='system_error_chance'>

# %%
plt.title('Data Loss Human vs Data Loss Machine')
sns.violinplot(data=dataset, x='data_loss_human', y='data_loss_machine', alpha=0.7, s=5)
# Out:
# <AxesSubplot:title={'center':'Data Loss Human vs Data Loss Machine'}, xlabel='data_loss_human', ylabel='data_loss_machine'>

# %%
sns.heatmap(dataset.corr(), cmap='RdBu', annot=True)
plt.title('Correlation Matrix')
# Out:
# Text(0.5, 1.0, 'Correlation Matrix')

# %%
sns.heatmap(dataset[cols].corr(), cmap='RdYlGn', annot=True)
plt.title('Correlation Matrix')
# Out:
# Text(0.5, 1.0, 'Correlation Matrix')
